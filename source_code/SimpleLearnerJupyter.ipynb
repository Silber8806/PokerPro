# %%
import pandas as pd
from poker import *
#from tqdm import tqdm


verbos=0
def sprint(message):
    if verbos==1:
        print(message)
# Out:
# sys executable C:\Users\shiras.PHILLIPS66\AppData\Local\Continuum\anaconda3\python.exe

# %%
class simpleLearnerPlayer(GenericPlayer):
    
    def policy():
        return 0
    def simpleLearnerCall(self,hand):
        """
        Made this function to make the decision for making call,fold and raise
        """
        hand_rank=[x for x,y in hand]
        hand_suit=[y for x,y in hand]
        
        if hand_suit[0]==hand_suit[1]:
            same_suit='Y'
        else:
            same_suit='N'
        self.dictionary_key=[hand_rank[0]+hand_rank[1]+same_suit,hand_rank[1]+hand_rank[0]+same_suit,'action']#saving the previous hand dictionary and action
        #print(self.hand_dictionary)
        #using same probability to play for first hand
        chance=random.random()
        if self.hand_dictionary[self.dictionary_key[0]]['sum_absolute_bet']==0:
            #print('first time this hand being played')
            if chance<0.33:
                sprint('first time randomply folding')
                self.dictionary_key[2]='fold'
                self.fold_bet()
            elif chance>=0.33 and chance<0.66:
                sprint('first time randomply calling')
                self.dictionary_key[2]='call'
                self.call_bet()
            else:
                sprint('first time randomply raising 20')
                self.dictionary_key[2]='raise'
                self.raise_bet(20)
        else:
            #print('repeated hand*************************************',self.hand_dictionary[self.dictionary_key[0]]['sum_bet'])
            #print('repeated absolute gain/lost',self.hand_dictionary[self.dictionary_key[0]]['sum_absolute_bet'])
            action=self.hand_dictionary[self.dictionary_key[0]]['sum_bet'].argmax()
            #if self.hand_dictionary[self.dictionary_key[0]]['sum_bet']>0:
            if action==0:    
                sprint('reapeated losing hand playing folding the hand')
                self.dictionary_key[2]='fold'
                self.fold_bet()
            elif action==1:
                sprint('repeated winning game , calling the bet')
                self.dictionary_key[2]='call'
                self.call_bet()
            else:
                raise_amount=20#round(100*self.hand_dictionary[self.dictionary_key[0]]['sum_bet']/self.hand_dictionary[self.dictionary_key[0]]['sum_absolute_bet'],0)
                #print('reapeated winning hand,raising by',raise_amount)
                self.dictionary_key[2]='raise'
                self.raise_bet(raise_amount)
        return None
               
    def update_SimpleLearnerReward(self):
        if self.dictionary_key[2]=='fold':
                    for i in range(2):#setting dictionary for both combination
                        self.hand_dictionary[self.dictionary_key[i]]['sum_absolute_bet']+=abs(self.balance_history[len(self.balance_history)-1][8])#updating hand dictionary
                        self.hand_dictionary[self.dictionary_key[i]]['sum_bet']+=np.array([self.balance_history[len(self.balance_history)-1][8],0,0])
        elif self.dictionary_key[2]=='call':
                    for i in range(2):#setting dictionary for both combination
                        self.hand_dictionary[self.dictionary_key[i]]['sum_absolute_bet']+=abs(self.balance_history[len(self.balance_history)-1][8])#updating hand dictionary
                        self.hand_dictionary[self.dictionary_key[i]]['sum_bet']+=np.array([0,self.balance_history[len(self.balance_history)-1][8],0])
        elif self.dictionary_key[2]=='raise':
                    for i in range(2):#setting dictionary for both combination
                        self.hand_dictionary[self.dictionary_key[i]]['sum_absolute_bet']+=abs(self.balance_history[len(self.balance_history)-1][8])#updating hand dictionary
                        self.hand_dictionary[self.dictionary_key[i]]['sum_bet']+=np.array([0,0,self.balance_history[len(self.balance_history)-1][8]])
        else:
            raise Exception('Action must select between fold, call or raise actions')
        return None    
    
    def repeat_action(self):
        if self.dictionary_key[2]=='call':
            sprint('repeating calling_bet*****************')
            self.call_bet()
        elif self.dictionary_key[2]=='raise':
            sprint('repeating raising_bet*****************')
            self.raise_bet(20)
        else:
            raise Exception('Check your code only two options for repeating actions should be call and raise')
        return None
    def bet_strategy(self,hand,river,opponents,call_bid,current_bid,pot,raise_allowed=False):
        """
        This player is a very simple learner, it looks at the first two card and make the decision on
        whether to call, raise or fold based on the first two call. Player has 3 simple policies, fold, call and raise by 20.
        we selected the same betting amount as we had for always call and always raise players in order to be able to compare the results.
        Player starts learning by playing games, at first he randomly selects between different policy (fold, call and raise) and sotre the
        final results "game net change" as its rewards. As it play more hands it starts to build the intuition about which hands/strategy give him better results.
        Player going to store the first two cards as a dictionary with rankings and whether they are the same suit or not as Y/N (for example if player has king 
        daimond and 2 club the key for the dictionary will be K2N & 2KN, but if we had King club and 2 club then the key for dictionary will be 2KY & K2Y). Then we append 
        the value of "game net change" after each game into the list. 
        As player plays more hand it starts utilizing the "game net change" value for each pair for cards. for example if player recieves 2KY it looks at "game net change"
        value from previous plays and calculates the probability of playing by adding all the "game net change" values in the list for 2KY hand and then divide that by adding
        the absolute value of "game net change".
        we use uniform random number generator between 0 and 1 
        1- if random value is less than calculated probability player raise
        2- if random value is greater caluculated probability but less than calculated probability +0.2 player call
        3- if random value is less than calculated probability +0.2 player fold.

        in order to avoid early elimination of some cards, if calculated probability became negative we change that to 0.1  which means player may raise the hand with 10 percent chance or call the hand with 0.1+0.2=0.3 30%
        probability

        use make bet function as part of class.
        on the player make attribute of player call history.
        make preflop wins as dictionary.
        learn about getter and setter ( encapsolation), later.
        make the function for making it suitless. get the card and make it suitless.

        """
        print('action is ',self.get_all_player_actions())
        print('current game is',self.current_game)
        print('balance history is ',self.balance_history)
        print('--------------------------------------------------------------------------')
        if len(self.balance_history)==0:
            self.number_of_finished_games=0
            #print(river)
            if self.short_memory!=self.current_game: #only making beting decision when we recieve the first two cards
                sprint('______________________________________________________________________')
                #print('hand',hand)
                #print('river',river)
                #print('river is Null')
                self.simpleLearnerCall(hand)
                self.short_memory=self.current_game
            else:
                self.repeat_action()
        else :#if len(self.balance_history)>self.number_of_finished_games:
            #print('river',river)
            if self.short_memory!=self.current_game:
                sprint('______________________________________________________________________')
                #print('hand',hand)
                #print('player previou hand',self.dictionary_key)
                #print('previous gain-lost is ',self.balance_history[len(self.balance_history)-1][8])
                #updating the reward 
                self.update_SimpleLearnerReward()
                
                self.simpleLearnerCall(hand)
                self.short_memory=self.current_game
                number_of_game=len(self.balance_history)
                #print('card1 is ',self.balance_history)
                #print('last_item is', self.balance_history[-1][-1])
                self.number_of_finished_games=len(self.balance_history)
                #print(self.number_of_finished_games)
                #print('current pot is',pot)
                #print('number of finished games are',self.number_of_finished_games)
            else:
                sprint('****************************************************repeating action')
                self.repeat_action()
            #sys.exit(0)
        return None

# %%
class AwarePlayer(GenericPlayer):
    def bet_strategy(self,hand,river,opponents,call_bid,current_bid,pot,raise_allowed=False):
        """
        This player uses different strategy from SimpleLearner Player to learn by playing hand. Unlike SimpleLearner that 
        randomly selects between fold, call and raise when there is no previous information, this player starts playing everyhand to
        learn whether it is a good hand or not. We expect this player to perform better by not losing the money by randomly folding or raising
        then it looks at the gain for call, if its negative its going to fold next time.
        Player learn about betting strategy by observing other players actions (bet, fold, raise) and the reward of their actions, then he decide his action based on the other result
        """
# Out:
# ['00', '10', '11', '20', '21', '22', '30', '31', '32', '33']

# %%
debug = 0 # to see detailed messages of simulation, put this to 1, think verbose mode
use_parallel = 0 # would not recommend using use_cache=1 on function simulate_win_odds due to not knowing if globals are thread or process safe.

# serial runs are guanteed unique repeatable results.  Parallel runs due to randomness of start times are not.  worth noting.

if __name__ == '__main__':
    print("starting poker simulation...(set debug=1 to see messages)")


    if debug == 1 and use_parallel == 1:
        raise Exception("Parallelism (use_parallel=1) is not supported with debug mode (debug=1)...set debug to 0")

    # defines all the simulations we will run
    simulations = {
       'tables': 1, # number of poker tables simulated
       'hands': 100, # number of hands the dealer will player, has to be greater than 2
       'balance': 100000000, # beginning balance in dollars, recommend > 10,000 unless you want player to run out of money
       'minimum_balance': 50, # minimum balance to join a table
       'simulations': [ # each dict in the list is a simulation to run    
            {
                'simulation_name': 'smart vs 5 all different types player', # name of simulation - reference for data analytics
                'player_types': [ # type of players, see the subclasses of GenericPlayer
                    AlwaysCallPlayer, # defines strategy of player 1
                    AlwaysCallPlayer, # defines strategy of player 1
                    AlwaysCallPlayer, # defines strategy of player 1
                    AlwaysCallPlayer, # defines strategy of player 1
                    #AlwaysRaisePlayer, # defines strategy of player 2
                    #CalculatedPlayer, # defines strategy of player 3
                    #GambleByProbabilityPlayer, # defines strategy of player 4
                    #ConservativePlayer, # defines strategy of player 5
                    #SmartPlayer, # defines strategy of player 6
                    #MonteCarloTreeSearchPlayer
                    simpleLearnerPlayer
                ]
            }    
        ]
    }

    random.seed(42) # gurantees standardized output for any given config

    run_all_simulations(simulations) # runs all the simulations in simulation variable
# Out:
# starting poker simulation...(set debug=1 to see messages)
# validating the simulation settings...
# finished the validation settings...
# beginning all simulation...
#
# simulation running: smart vs 5 all different types player
# running job in serial fashion
# running table_id 1 for scenario: smart vs 5 all different types player (serial processing)
# action is  [('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000001
# balance history is  []
# --------------------------------------------------------------------------
# action is  []
# current game is 1000002
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_4', 'call', 0)]
# current game is 1000003
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('card', [Card(rank='4', suit='hearts'), Card(rank='4', suit='clubs'), Card(rank='A', suit='hearts')]), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000003
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('card', [Card(rank='4', suit='hearts'), Card(rank='4', suit='clubs'), Card(rank='A', suit='hearts')]), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('card', [Card(rank='4', suit='hearts'), Card(rank='4', suit='clubs'), Card(rank='A', suit='hearts'), Card(rank='A', suit='clubs')]), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000003
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('card', [Card(rank='4', suit='hearts'), Card(rank='4', suit='clubs'), Card(rank='A', suit='hearts')]), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('card', [Card(rank='4', suit='hearts'), Card(rank='4', suit='clubs'), Card(rank='A', suit='hearts'), Card(rank='A', suit='clubs')]), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('card', [Card(rank='4', suit='hearts'), Card(rank='4', suit='clubs'), Card(rank='A', suit='hearts'), Card(rank='A', suit='clubs'), Card(rank='J', suit='diamonds')]), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000003
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000004
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('card', [Card(rank='J', suit='diamonds'), Card(rank='6', suit='hearts'), Card(rank='6', suit='diamonds')]), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000004
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('card', [Card(rank='J', suit='diamonds'), Card(rank='6', suit='hearts'), Card(rank='6', suit='diamonds')]), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('card', [Card(rank='J', suit='diamonds'), Card(rank='6', suit='hearts'), Card(rank='6', suit='diamonds'), Card(rank='7', suit='spades')]), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000004
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('card', [Card(rank='J', suit='diamonds'), Card(rank='6', suit='hearts'), Card(rank='6', suit='diamonds')]), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('card', [Card(rank='J', suit='diamonds'), Card(rank='6', suit='hearts'), Card(rank='6', suit='diamonds'), Card(rank='7', suit='spades')]), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('card', [Card(rank='J', suit='diamonds'), Card(rank='6', suit='hearts'), Card(rank='6', suit='diamonds'), Card(rank='7', suit='spades'), Card(rank='Q', suit='hearts')]), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000004
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000005
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000006
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('card', [Card(rank='5', suit='spades'), Card(rank='K', suit='hearts'), Card(rank='5', suit='diamonds')]), ('player', 'players_4', 'call', 0)]
# current game is 1000006
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('card', [Card(rank='5', suit='spades'), Card(rank='K', suit='hearts'), Card(rank='5', suit='diamonds')]), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('card', [Card(rank='5', suit='spades'), Card(rank='K', suit='hearts'), Card(rank='5', suit='diamonds'), Card(rank='A', suit='diamonds')]), ('player', 'players_4', 'call', 0)]
# current game is 1000006
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('card', [Card(rank='5', suit='spades'), Card(rank='K', suit='hearts'), Card(rank='5', suit='diamonds')]), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('card', [Card(rank='5', suit='spades'), Card(rank='K', suit='hearts'), Card(rank='5', suit='diamonds'), Card(rank='A', suit='diamonds')]), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('card', [Card(rank='5', suit='spades'), Card(rank='K', suit='hearts'), Card(rank='5', suit='diamonds'), Card(rank='A', suit='diamonds'), Card(rank='3', suit='spades')]), ('player', 'players_4', 'call', 0)]
# current game is 1000006
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0]]
# --------------------------------------------------------------------------
# action is  []
# current game is 1000007
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_4', 'call', 0)]
# current game is 1000008
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000009
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('card', [Card(rank='8', suit='clubs'), Card(rank='5', suit='diamonds'), Card(rank='7', suit='clubs')]), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000009
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('card', [Card(rank='8', suit='clubs'), Card(rank='5', suit='diamonds'), Card(rank='7', suit='clubs')]), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('card', [Card(rank='8', suit='clubs'), Card(rank='5', suit='diamonds'), Card(rank='7', suit='clubs'), Card(rank='A', suit='clubs')]), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000009
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('card', [Card(rank='8', suit='clubs'), Card(rank='5', suit='diamonds'), Card(rank='7', suit='clubs')]), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('card', [Card(rank='8', suit='clubs'), Card(rank='5', suit='diamonds'), Card(rank='7', suit='clubs'), Card(rank='A', suit='clubs')]), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('card', [Card(rank='8', suit='clubs'), Card(rank='5', suit='diamonds'), Card(rank='7', suit='clubs'), Card(rank='A', suit='clubs'), Card(rank='Q', suit='spades')]), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000009
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000010
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000009', 'lost', 'lost_game', 'None', 'high_card', 100000000, 100000005.0, 99999995.0, -10.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('card', [Card(rank='5', suit='hearts'), Card(rank='10', suit='diamonds'), Card(rank='J', suit='diamonds')])]
# current game is 1000010
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000009', 'lost', 'lost_game', 'None', 'high_card', 100000000, 100000005.0, 99999995.0, -10.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('card', [Card(rank='5', suit='hearts'), Card(rank='10', suit='diamonds'), Card(rank='J', suit='diamonds')]), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('card', [Card(rank='5', suit='hearts'), Card(rank='10', suit='diamonds'), Card(rank='J', suit='diamonds'), Card(rank='8', suit='diamonds')])]
# current game is 1000010
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000009', 'lost', 'lost_game', 'None', 'high_card', 100000000, 100000005.0, 99999995.0, -10.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('card', [Card(rank='5', suit='hearts'), Card(rank='10', suit='diamonds'), Card(rank='J', suit='diamonds')]), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('card', [Card(rank='5', suit='hearts'), Card(rank='10', suit='diamonds'), Card(rank='J', suit='diamonds'), Card(rank='8', suit='diamonds')]), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('card', [Card(rank='5', suit='hearts'), Card(rank='10', suit='diamonds'), Card(rank='J', suit='diamonds'), Card(rank='8', suit='diamonds'), Card(rank='9', suit='clubs')])]
# current game is 1000010
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000009', 'lost', 'lost_game', 'None', 'high_card', 100000000, 100000005.0, 99999995.0, -10.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000011
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000009', 'lost', 'lost_game', 'None', 'high_card', 100000000, 100000005.0, 99999995.0, -10.0], ['1000010', 'lost', 'lost_game', 'small', 'high_card', 100000000, 99999995.0, 99999985.0, -10.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000011
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000009', 'lost', 'lost_game', 'None', 'high_card', 100000000, 100000005.0, 99999995.0, -10.0], ['1000010', 'lost', 'lost_game', 'small', 'high_card', 100000000, 99999995.0, 99999985.0, -10.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000011
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000009', 'lost', 'lost_game', 'None', 'high_card', 100000000, 100000005.0, 99999995.0, -10.0], ['1000010', 'lost', 'lost_game', 'small', 'high_card', 100000000, 99999995.0, 99999985.0, -10.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('card', [Card(rank='9', suit='spades'), Card(rank='J', suit='clubs'), Card(rank='2', suit='spades')]), ('player', 'players_4', 'call', 0)]
# current game is 1000011
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000009', 'lost', 'lost_game', 'None', 'high_card', 100000000, 100000005.0, 99999995.0, -10.0], ['1000010', 'lost', 'lost_game', 'small', 'high_card', 100000000, 99999995.0, 99999985.0, -10.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('card', [Card(rank='9', suit='spades'), Card(rank='J', suit='clubs'), Card(rank='2', suit='spades')]), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000011
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000009', 'lost', 'lost_game', 'None', 'high_card', 100000000, 100000005.0, 99999995.0, -10.0], ['1000010', 'lost', 'lost_game', 'small', 'high_card', 100000000, 99999995.0, 99999985.0, -10.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('card', [Card(rank='9', suit='spades'), Card(rank='J', suit='clubs'), Card(rank='2', suit='spades')]), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000011
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000009', 'lost', 'lost_game', 'None', 'high_card', 100000000, 100000005.0, 99999995.0, -10.0], ['1000010', 'lost', 'lost_game', 'small', 'high_card', 100000000, 99999995.0, 99999985.0, -10.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('card', [Card(rank='9', suit='spades'), Card(rank='J', suit='clubs'), Card(rank='2', suit='spades')]), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('card', [Card(rank='9', suit='spades'), Card(rank='J', suit='clubs'), Card(rank='2', suit='spades'), Card(rank='4', suit='clubs')]), ('player', 'players_4', 'call', 0)]
# current game is 1000011
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000009', 'lost', 'lost_game', 'None', 'high_card', 100000000, 100000005.0, 99999995.0, -10.0], ['1000010', 'lost', 'lost_game', 'small', 'high_card', 100000000, 99999995.0, 99999985.0, -10.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('card', [Card(rank='9', suit='spades'), Card(rank='J', suit='clubs'), Card(rank='2', suit='spades')]), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('card', [Card(rank='9', suit='spades'), Card(rank='J', suit='clubs'), Card(rank='2', suit='spades'), Card(rank='4', suit='clubs')]), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000011
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000009', 'lost', 'lost_game', 'None', 'high_card', 100000000, 100000005.0, 99999995.0, -10.0], ['1000010', 'lost', 'lost_game', 'small', 'high_card', 100000000, 99999995.0, 99999985.0, -10.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('card', [Card(rank='9', suit='spades'), Card(rank='J', suit='clubs'), Card(rank='2', suit='spades')]), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('card', [Card(rank='9', suit='spades'), Card(rank='J', suit='clubs'), Card(rank='2', suit='spades'), Card(rank='4', suit='clubs')]), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000011
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000009', 'lost', 'lost_game', 'None', 'high_card', 100000000, 100000005.0, 99999995.0, -10.0], ['1000010', 'lost', 'lost_game', 'small', 'high_card', 100000000, 99999995.0, 99999985.0, -10.0]]
# --------------------------------------------------------------------------
# action is  [('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('card', [Card(rank='9', suit='spades'), Card(rank='J', suit='clubs'), Card(rank='2', suit='spades')]), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('card', [Card(rank='9', suit='spades'), Card(rank='J', suit='clubs'), Card(rank='2', suit='spades'), Card(rank='4', suit='clubs')]), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'bet', 20), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('card', [Card(rank='9', suit='spades'), Card(rank='J', suit='clubs'), Card(rank='2', suit='spades'), Card(rank='4', suit='clubs'), Card(rank='A', suit='diamonds')]), ('player', 'players_4', 'call', 0)]
# current game is 1000011
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000009', 'lost', 'lost_game', 'None', 'high_card', 100000000, 100000005.0, 99999995.0, -10.0], ['1000010', 'lost', 'lost_game', 'small', 'high_card', 100000000, 99999995.0, 99999985.0, -10.0]]
# --------------------------------------------------------------------------
# ...
# --------------------------------------------------------------------------
# action is  [('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('card', [Card(rank='6', suit='clubs'), Card(rank='3', suit='hearts'), Card(rank='2', suit='diamonds')]), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('card', [Card(rank='6', suit='clubs'), Card(rank='3', suit='hearts'), Card(rank='2', suit='diamonds'), Card(rank='2', suit='hearts')]), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0), ('player', 'players_5', 'call', 0), ('player', 'players_1', 'call', 0), ('card', [Card(rank='6', suit='clubs'), Card(rank='3', suit='hearts'), Card(rank='2', suit='diamonds'), Card(rank='2', suit='hearts'), Card(rank='J', suit='clubs')]), ('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000098
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000009', 'lost', 'lost_game', 'None', 'high_card', 100000000, 100000005.0, 99999995.0, -10.0], ['1000010', 'lost', 'lost_game', 'small', 'high_card', 100000000, 99999995.0, 99999985.0, -10.0], ['1000011', 'lost', 'lost_game', 'big', 'high_card', 100000000, 99999985.0, 99999815.0, -170.0], ['1000012', 'won', 'won_game', 'None', 'flush', 100000000, 99999815.0, 99999855.0, 40.0], ['1000013', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999855.0, 99999685.0, -170.0], ['1000014', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999685.0, 99999675.0, -10.0], ['1000015', 'lost', 'lost_game', 'small', 'high_card', 100000000, 99999675.0, 99999565.0, -110.0], ['1000016', 'lost', 'fold', 'big', 'None', 100000000, 99999565.0, 99999555.0, -10.0], ['1000017', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999555.0, 99999545.0, -10.0], ['1000018', 'lost', 'lost_game', 'None', 'high_card', 100000000, 99999545.0, 99999375.0, -170.0], ['1000019', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999375.0, 99999365.0, -10.0], ['1000020', 'lost', 'fold', 'small', 'None', 100000000, 99999365.0, 99999360.0, -5.0], ['1000021', 'won', 'won_game', 'big', 'three_of_kind', 100000000, 99999360.0, 99999400.0, 40.0], ['1000022', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999400.0, 99999390.0, -10.0], ['1000023', 'won', 'won_game', 'None', 'straight', 100000000, 99999390.0, 99999430.0, 40.0], ['1000024', 'lost', 'lost_game', 'None', 'high_card', 100000000, 99999430.0, 99999260.0, -170.0], ['1000025', 'lost', 'lost_game', 'small', 'two_pair', 100000000, 99999260.0, 99999250.0, -10.0], ['1000026', 'lost', 'lost_game', 'big', 'two_pair', 100000000, 99999250.0, 99999080.0, -170.0], ['1000027', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999080.0, 99999070.0, -10.0], ['1000028', 'lost', 'lost_game', 'None', 'high_card', 100000000, 99999070.0, 99999060.0, -10.0], ['1000029', 'lost', 'lost_game', 'None', 'high_card', 100000000, 99999060.0, 99999050.0, -10.0], ['1000030', 'won', 'won_game', 'small', 'one_pair', 100000000, 99999050.0, 99999490.0, 440.0], ['1000031', 'lost', 'fold', 'big', 'None', 100000000, 99999490.0, 99999480.0, -10.0], ['1000032', 'lost', 'fold', 'None', 'None', 100000000, 99999480.0, 99999480.0, 0.0], ['1000033', 'lost', 'fold', 'None', 'None', 100000000, 99999480.0, 99999480.0, 0.0], ['1000034', 'lost', 'fold', 'None', 'None', 100000000, 99999480.0, 99999480.0, 0.0], ['1000035', 'lost', 'fold', 'small', 'None', 100000000, 99999480.0, 99999475.0, -5.0], ['1000036', 'lost', 'lost_game', 'big', 'two_pair', 100000000, 99999475.0, 99999465.0, -10.0], ['1000037', 'won', 'won_game', 'None', 'straight', 100000000, 99999465.0, 99999505.0, 40.0], ['1000038', 'won', 'won_game', 'None', 'straight', 100000000, 99999505.0, 99999760.0, 255.0], ['1000039', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999760.0, 99999750.0, -10.0], ['1000040', 'lost', 'fold', 'small', 'None', 100000000, 99999750.0, 99999745.0, -5.0], ['1000041', 'lost', 'fold', 'big', 'None', 100000000, 99999745.0, 99999735.0, -10.0], ['1000042', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999735.0, 99999585.0, -150.0], ['1000043', 'lost', 'lost_game', 'None', 'straight', 100000000, 99999585.0, 99999415.0, -170.0], ['10 ...
# --------------------------------------------------------------------------
# action is  [('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000099
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000009', 'lost', 'lost_game', 'None', 'high_card', 100000000, 100000005.0, 99999995.0, -10.0], ['1000010', 'lost', 'lost_game', 'small', 'high_card', 100000000, 99999995.0, 99999985.0, -10.0], ['1000011', 'lost', 'lost_game', 'big', 'high_card', 100000000, 99999985.0, 99999815.0, -170.0], ['1000012', 'won', 'won_game', 'None', 'flush', 100000000, 99999815.0, 99999855.0, 40.0], ['1000013', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999855.0, 99999685.0, -170.0], ['1000014', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999685.0, 99999675.0, -10.0], ['1000015', 'lost', 'lost_game', 'small', 'high_card', 100000000, 99999675.0, 99999565.0, -110.0], ['1000016', 'lost', 'fold', 'big', 'None', 100000000, 99999565.0, 99999555.0, -10.0], ['1000017', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999555.0, 99999545.0, -10.0], ['1000018', 'lost', 'lost_game', 'None', 'high_card', 100000000, 99999545.0, 99999375.0, -170.0], ['1000019', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999375.0, 99999365.0, -10.0], ['1000020', 'lost', 'fold', 'small', 'None', 100000000, 99999365.0, 99999360.0, -5.0], ['1000021', 'won', 'won_game', 'big', 'three_of_kind', 100000000, 99999360.0, 99999400.0, 40.0], ['1000022', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999400.0, 99999390.0, -10.0], ['1000023', 'won', 'won_game', 'None', 'straight', 100000000, 99999390.0, 99999430.0, 40.0], ['1000024', 'lost', 'lost_game', 'None', 'high_card', 100000000, 99999430.0, 99999260.0, -170.0], ['1000025', 'lost', 'lost_game', 'small', 'two_pair', 100000000, 99999260.0, 99999250.0, -10.0], ['1000026', 'lost', 'lost_game', 'big', 'two_pair', 100000000, 99999250.0, 99999080.0, -170.0], ['1000027', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999080.0, 99999070.0, -10.0], ['1000028', 'lost', 'lost_game', 'None', 'high_card', 100000000, 99999070.0, 99999060.0, -10.0], ['1000029', 'lost', 'lost_game', 'None', 'high_card', 100000000, 99999060.0, 99999050.0, -10.0], ['1000030', 'won', 'won_game', 'small', 'one_pair', 100000000, 99999050.0, 99999490.0, 440.0], ['1000031', 'lost', 'fold', 'big', 'None', 100000000, 99999490.0, 99999480.0, -10.0], ['1000032', 'lost', 'fold', 'None', 'None', 100000000, 99999480.0, 99999480.0, 0.0], ['1000033', 'lost', 'fold', 'None', 'None', 100000000, 99999480.0, 99999480.0, 0.0], ['1000034', 'lost', 'fold', 'None', 'None', 100000000, 99999480.0, 99999480.0, 0.0], ['1000035', 'lost', 'fold', 'small', 'None', 100000000, 99999480.0, 99999475.0, -5.0], ['1000036', 'lost', 'lost_game', 'big', 'two_pair', 100000000, 99999475.0, 99999465.0, -10.0], ['1000037', 'won', 'won_game', 'None', 'straight', 100000000, 99999465.0, 99999505.0, 40.0], ['1000038', 'won', 'won_game', 'None', 'straight', 100000000, 99999505.0, 99999760.0, 255.0], ['1000039', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999760.0, 99999750.0, -10.0], ['1000040', 'lost', 'fold', 'small', 'None', 100000000, 99999750.0, 99999745.0, -5.0], ['1000041', 'lost', 'fold', 'big', 'None', 100000000, 99999745.0, 99999735.0, -10.0], ['1000042', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999735.0, 99999585.0, -150.0], ['1000043', 'lost', 'lost_game', 'None', 'straight', 100000000, 99999585.0, 99999415.0, -170.0], ['10 ...
# --------------------------------------------------------------------------
# action is  [('player', 'players_2', 'call', 0), ('player', 'players_3', 'call', 0), ('player', 'players_4', 'call', 0)]
# current game is 1000100
# balance history is  [['1000001', 'lost', 'fold', 'big', 'None', 100000000, 100000000, 99999990, -10], ['1000002', 'lost', 'fold', 'None', 'None', 100000000, 99999990, 99999990, 0], ['1000003', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999990, 99999980, -10], ['1000004', 'won', 'won_game', 'None', 'one_pair', 100000000, 99999980, 100000020.0, 40.0], ['1000005', 'lost', 'fold', 'small', 'None', 100000000, 100000020.0, 100000015.0, -5.0], ['1000006', 'lost', 'lost_game', 'big', 'one_pair', 100000000, 100000015.0, 100000005.0, -10.0], ['1000007', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000008', 'lost', 'fold', 'None', 'None', 100000000, 100000005.0, 100000005.0, 0.0], ['1000009', 'lost', 'lost_game', 'None', 'high_card', 100000000, 100000005.0, 99999995.0, -10.0], ['1000010', 'lost', 'lost_game', 'small', 'high_card', 100000000, 99999995.0, 99999985.0, -10.0], ['1000011', 'lost', 'lost_game', 'big', 'high_card', 100000000, 99999985.0, 99999815.0, -170.0], ['1000012', 'won', 'won_game', 'None', 'flush', 100000000, 99999815.0, 99999855.0, 40.0], ['1000013', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999855.0, 99999685.0, -170.0], ['1000014', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999685.0, 99999675.0, -10.0], ['1000015', 'lost', 'lost_game', 'small', 'high_card', 100000000, 99999675.0, 99999565.0, -110.0], ['1000016', 'lost', 'fold', 'big', 'None', 100000000, 99999565.0, 99999555.0, -10.0], ['1000017', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999555.0, 99999545.0, -10.0], ['1000018', 'lost', 'lost_game', 'None', 'high_card', 100000000, 99999545.0, 99999375.0, -170.0], ['1000019', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999375.0, 99999365.0, -10.0], ['1000020', 'lost', 'fold', 'small', 'None', 100000000, 99999365.0, 99999360.0, -5.0], ['1000021', 'won', 'won_game', 'big', 'three_of_kind', 100000000, 99999360.0, 99999400.0, 40.0], ['1000022', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999400.0, 99999390.0, -10.0], ['1000023', 'won', 'won_game', 'None', 'straight', 100000000, 99999390.0, 99999430.0, 40.0], ['1000024', 'lost', 'lost_game', 'None', 'high_card', 100000000, 99999430.0, 99999260.0, -170.0], ['1000025', 'lost', 'lost_game', 'small', 'two_pair', 100000000, 99999260.0, 99999250.0, -10.0], ['1000026', 'lost', 'lost_game', 'big', 'two_pair', 100000000, 99999250.0, 99999080.0, -170.0], ['1000027', 'lost', 'lost_game', 'None', 'two_pair', 100000000, 99999080.0, 99999070.0, -10.0], ['1000028', 'lost', 'lost_game', 'None', 'high_card', 100000000, 99999070.0, 99999060.0, -10.0], ['1000029', 'lost', 'lost_game', 'None', 'high_card', 100000000, 99999060.0, 99999050.0, -10.0], ['1000030', 'won', 'won_game', 'small', 'one_pair', 100000000, 99999050.0, 99999490.0, 440.0], ['1000031', 'lost', 'fold', 'big', 'None', 100000000, 99999490.0, 99999480.0, -10.0], ['1000032', 'lost', 'fold', 'None', 'None', 100000000, 99999480.0, 99999480.0, 0.0], ['1000033', 'lost', 'fold', 'None', 'None', 100000000, 99999480.0, 99999480.0, 0.0], ['1000034', 'lost', 'fold', 'None', 'None', 100000000, 99999480.0, 99999480.0, 0.0], ['1000035', 'lost', 'fold', 'small', 'None', 100000000, 99999480.0, 99999475.0, -5.0], ['1000036', 'lost', 'lost_game', 'big', 'two_pair', 100000000, 99999475.0, 99999465.0, -10.0], ['1000037', 'won', 'won_game', 'None', 'straight', 100000000, 99999465.0, 99999505.0, 40.0], ['1000038', 'won', 'won_game', 'None', 'straight', 100000000, 99999505.0, 99999760.0, 255.0], ['1000039', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999760.0, 99999750.0, -10.0], ['1000040', 'lost', 'fold', 'small', 'None', 100000000, 99999750.0, 99999745.0, -5.0], ['1000041', 'lost', 'fold', 'big', 'None', 100000000, 99999745.0, 99999735.0, -10.0], ['1000042', 'lost', 'lost_game', 'None', 'one_pair', 100000000, 99999735.0, 99999585.0, -150.0], ['1000043', 'lost', 'lost_game', 'None', 'straight', 100000000, 99999585.0, 99999415.0, -170.0], ['10 ...
# --------------------------------------------------------------------------
# simulation finished: smart vs 5 all different types player - time_required: 1.12 seconds
#
# finished all simulation
